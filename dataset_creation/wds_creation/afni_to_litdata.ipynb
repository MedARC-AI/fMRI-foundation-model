# %% [markdown]
# ## Import dependencies

# %%
# Standard Library Imports
import os
import sys
from subprocess import call, DEVNULL
import json
import time
import traceback
import asyncio
import aiohttp
import re

# Third-Party Library Imports
import numpy as np
import boto3
from botocore import UNSIGNED
from botocore.client import Config
import webdataset as wds
import nibabel as nib
import pickle as pkl
from einops import rearrange
import torchvision.transforms as transforms
from PIL import Image
import torch
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from sklearn.preprocessing import StandardScaler
from litdata import optimize

# %% [markdown]
# ## Helper functions

# %%
def reshape_to_2d(tensor):
    return rearrange(tensor, 'b h w c -> (b h) (c w)')

def reshape_to_original(tensor_2d, b=300, h=64, w=64, c=48):
    return rearrange(tensor_2d, '(b h) (c w) -> b h w c', b=b, h=h, w=w, c=c)

def header_to_dict(header):
    readable_header = {}
    for key, value in header.items():
        readable_header[key] = value
    return readable_header

def temporal_interp1d(fmri_data, change_TR):
    original_time_points = np.arange(fmri_data.shape[0])  # Time points: 0, 1, 2, ..., T-1
    new_time_points = np.arange(0, fmri_data.shape[0], change_TR)  # New time points: 0, 2, 4, ...

    reshaped_data = fmri_data.reshape(fmri_data.shape[0], -1)  # Reshape to (T, X*Y*Z)
    interpolate = interp1d(original_time_points, reshaped_data, kind='linear', axis=0, bounds_error=False, fill_value="extrapolate")
    resampled_fmri_data = interpolate(new_time_points).reshape((len(new_time_points),) + fmri_data.shape[1:])
    return resampled_fmri_data
    
def is_interactive():
    import __main__ as main
    return not hasattr(main, '__file__')

# %% [markdown]
# ## Create dir to save dataset

# %%
temp_folder = '/scratch/temp_MNIs'
os.makedirs(temp_folder, exist_ok=True)
print(temp_folder)

# wds_folder = os.getcwd()+'/openneuro_wds'
# prefix = 'fmri_foundation_datasets/openneuro_MNI/'

wds_folder = os.getcwd()+'/nsd_litdata' #'/nsd_wds'
prefix = 'fmri_foundation_datasets/NSD_MNI/'

os.makedirs(wds_folder, exist_ok=True)
print(wds_folder)

s3_output_folder_name = prefix.split('/')[1]+'_litdata'
print(s3_output_folder_name)
# Out:
# /scratch/temp_MNIs
# /weka/proj-fmri/paulscotti/fMRI-foundation-model/dataset_creation/wds_creation/nsd_litdata
# NSD_MNI_litdata

# %%
# # delete saved files
# command = f"rm {temp_folder}/*"
# call(command,shell=True)

# delete saved files
command = f"rm {wds_folder}/*"
call(command,shell=True)
# Out:
# 0

# %% [markdown]
# ## Job

# %%
s3 = boto3.client('s3')
bucket_name = 'proj-fmri'

paginator = s3.get_paginator('list_objects_v2')
file_name_list = []
for page in paginator.paginate(Bucket=bucket_name, Prefix=prefix):
    for obj in page.get('Contents', []):
        file_name = obj['Key']
        file_name_list.append(file_name)
print("len(file_name_list) =", len(file_name_list))
# Out:
# len(file_name_list) = 3696

# %%
# command = f"aws s3 sync s3://proj-fmri/{prefix[:-1]} {temp_folder}"
# print(command)
# call(command, shell=True, stdout=DEVNULL, stderr=DEVNULL)

# # print(f"\nchecking for file {file_name_list[-1]}...")
# # if not os.path.exists(file_name_list[-1]):
# #     time.sleep(20)

# print("\nready!")

# %%
from collections import defaultdict

# Initialize a dictionary to hold the categorized file paths
datasets = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))
datasets_minmean = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

for file_name in file_name_list:
    parts = file_name.split('/')
    dataset_id = parts[2]
    subject_parts = parts[3].split('_')
    subject_id = subject_parts[0]  # Extract the subject identifier

    # Check for session identifier, default to "ses-01" if not present
    session_id = "ses-01"
    for part in subject_parts:
        if part.startswith("ses-"):
            session_id = part
            break
    
    datasets[dataset_id][subject_id][session_id].append(file_name)

# %%
# TRs_per_sample = 32
# max_samples_per_tar = 30 # try to translate to around 1 Gb per tar
# max_TRs_per_tar = max_samples_per_tar * TRs_per_sample

# current_dataset = None
# current_subject = None

# MNI_mask = nib.load("/weka/proj-fmri/paulscotti/fMRI-foundation-model/dataset_creation/afni_conversion/tpl-MNI152NLin2009cAsym_res-02_T1w_brain.nii.gz").get_fdata()
# MNI_mask[MNI_mask>0]=1
# MNI_mask = MNI_mask.astype(bool)

# for dataset_id in ['ses-prffloc']:#list(datasets.keys()):
#     for subject_id in list(datasets[dataset_id].keys()):
#         for session_id in list(datasets[dataset_id][subject_id].keys()):
#             print(f"Processing {dataset_id} {subject_id} {session_id}")
#             # first get min and max values across all runs in session
#             run_count = 0
#             for file_name in datasets[dataset_id][subject_id][session_id]:
#                 temp_file_path = f"{temp_folder}/{file_name.split('/')[2]}/{file_name.split('/')[3]}"
#                 # temp_folder + '/' + file_name.split('/')[2] + '_' + file_name.split('/')[-1]
            
#                 # if not os.path.exists(temp_file_path):
#                 #     # s3.download_file(bucket_name, file_name, temp_file_path)
#                 #     command = f"aws s3 cp s3://proj-fmri/{file_name} {temp_file_path}"
#                 #     call(command,shell=True)

#                 if not os.path.exists(temp_file_path):
#                     raise Exception("s3 file not found")
            
#                 func_nii = nib.load(temp_file_path).get_fdata()
#                 func_nii = np.moveaxis(func_nii, -1, 0)
#                 data = func_nii[:,MNI_mask] # find normalization values only inside of the MNI brain mask

#                 # ignore outliers via standard deviation exclusion
#                 low = data.mean() - 2 * data.std()
#                 high = data.mean() + 2 * data.std()
#                 filtered_data = data[(data > low) & (data < high)]
#                 min_val = np.min(filtered_data)
#                 max_val = np.max(filtered_data)
                
#                 run_count +=1
#                 if run_count==1: 
#                     min = min_val
#                     max = max_val
#                 else:
#                     min += min_val
#                     max += max_val
                    
#             min /= run_count
#             max /= run_count
#             print(f"min = {min} | max = {max}")
#             datasets_minmean[dataset_id][subject_id][session_id] = [min,max]
# Out:
# Processing ses-prffloc sub-01 ses-prffloc
# min = 0.0 | max = 1058.3333333333333
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 52
#      50 max /= run_count
#      51 print(f"min = {min} | max = {max}")
# ---> 52 datasets_minmean[dataset_id][subject_id][session_id] = [min,max]
#
# KeyError: 'ses-prffloc'

# %%
# with open('minmax_datasets.json', 'w') as file:
#     json.dump(datasets_minmean, file)
# json_dump = True
# print("done!")

# %%
with open('minmax_datasets.json', 'r') as file:
    datasets_minmean = json.load(file)
print("loaded!")
# Out:
# loaded!

# %%
def making_litdata(file_name):
    parts = file_name.split('/')
    dataset_id = parts[2]
    subject_parts = parts[3].split('_')
    subject_id = subject_parts[0]  # Extract the subject identifier
    
    # Check for session identifier, default to "ses-01" if not present
    session_id = "ses-01"
    for part in subject_parts:
        if part.startswith("ses-"):
            session_id = part
            break
            
    minmax = datasets_minmean[dataset_id][subject_id][session_id]
    min, max = minmax[0], minmax[1]
    
    temp_file_path = f"{temp_folder}/{file_name.split('/')[2]}/{file_name.split('/')[3]}"
    # temp_file_path = temp_folder + '/' + file_name.split('/')[2] + '_' + file_name.split('/')[-1]

    # if not os.path.exists(temp_file_path):
    #     # s3.download_file(bucket_name, file_name, temp_file_path)
    #     command = f"aws s3 cp s3://proj-fmri/{file_name} {temp_file_path}"
    #     call(command,shell=True)

    if not os.path.exists(temp_file_path):
        raise Exception("s3 file not found")
    
    func_nii = nib.load(temp_file_path).get_fdata()
    func_nii = np.moveaxis(func_nii, -1, 0)
    func_nii = func_nii[:,6:94,8:112,10:82].astype(np.float16) # [T, 97, 115, 97] to [T, 88, 104, 72]

    # normalize by min max
    func_nii = (func_nii - min) / (max - min)
    
    data = {
        "func": func_nii, 
    }
    return data

# %%
filtered_file_name_list = [file for file in file_name_list if "prffloc" not in file]
print("prffloc encountered an error so for sake of time im just skipping it")

optimize(
    fn=making_litdata,  # The function applied over each input.
    inputs=filtered_file_name_list,  # Provide any inputs. The fn is applied on each item.
    output_dir=wds_folder,  # The directory where the optimized data are stored.
    num_workers=16,  # The number of workers. The inputs are distributed among them.
    chunk_bytes="256MB"  # The maximum number of bytes to write into a data chunk.
)
# Out:
# prffloc encountered an error so for sake of time im just skipping it
# Create an account on https://lightning.ai/ to optimize your data faster using multiple nodes and large machines.
# Storing the files under /weka/proj-fmri/paulscotti/fMRI-foundation-model/dataset_creation/wds_creation/nsd_litdata
# Setup started with fast_dev_run=False.
# Setup finished in 0.146 seconds. Found 3600 items to process.
# Starting 20 workers with 3600 items.
# Workers are ready ! Starting data processing...
# Progress:   0%|                                                                 | 0/3600 [00:00<?, ?it/s]
# Rank 5 inferred the following `['numpy']` data format.
# Rank 6 inferred the following `['numpy']` data format.
# Rank 12 inferred the following `['numpy']` data format.
# Rank 3 inferred the following `['numpy']` data format.
# Rank 7 inferred the following `['numpy']` data format.
# Rank 2 inferred the following `['numpy']` data format.
# Rank 8 inferred the following `['numpy']` data format.
# Rank 17 inferred the following `['numpy']` data format.
# Rank 18 inferred the following `['numpy']` data format.
# Rank 11 inferred the following `['numpy']` data format.
# Rank 1 inferred the following `['numpy']` data format.
# Rank 13 inferred the following `['numpy']` data format.
# Rank 10 inferred the following `['numpy']` data format.
# Rank 15 inferred the following `['numpy']` data format.
# Rank 9 inferred the following `['numpy']` data format.
# Rank 4 inferred the following `['numpy']` data format.
# Rank 19 inferred the following `['numpy']` data format.
# Rank 16 inferred the following `['numpy']` data format.
# Rank 14 inferred the following `['numpy']` data format.
# Rank 0 inferred the following `['numpy']` data format.
# Worker 6 is terminating.
# Worker 6 is done.
# Worker 4 is terminating.
# Worker 8 is terminating.
# Worker 4 is done.
# Worker 8 is done.
# Worker 19 is terminating.
# Worker 19 is done.
# Worker 12 is terminating.
# Worker 1 is terminating.
# Worker 12 is done.
# Worker 1 is done.
# Worker 3 is terminating.
# Worker 3 is done.
# Worker 0 is terminating.
# Worker 2 is terminating.
# Worker 0 is done.
# Worker 2 is done.
# Worker 14 is terminating.
# Worker 14 is done.
# Worker 16 is terminating.
# Worker 11 is terminating.
# Worker 16 is done.
# Worker 11 is done.
# Worker 13 is terminating.
# Worker 5 is terminating.
# Worker 13 is done.
# Worker 5 is done.
# Worker 7 is terminating.
# Worker 7 is done.
# Worker 9 is terminating.
# Worker 9 is done.
# Worker 15 is terminating.
# Worker 15 is done.
# Worker 18 is terminating.
# Worker 18 is done.
# Worker 10 is terminating.
# Worker 10 is done.
# Worker 17 is terminating.
# Worker 17 is done.
# Workers are finished.
# Finished data processing!

# %%
command = f"aws s3 cp --recursive {wds_folder} s3://proj-fmri/fmri_foundation_datasets/{s3_output_folder_name}"
call(command,shell=True)
# Out:
# upload: nsd_litdata/chunk-0-0.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-0.bin
# upload: nsd_litdata/chunk-0-10.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-10.bin
# upload: nsd_litdata/chunk-0-1.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-1.bin
# upload: nsd_litdata/chunk-0-100.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-100.bin
# upload: nsd_litdata/chunk-0-101.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-101.bin
# upload: nsd_litdata/chunk-0-102.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-102.bin
# upload: nsd_litdata/chunk-0-104.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-104.bin
# upload: nsd_litdata/chunk-0-106.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-106.bin
# upload: nsd_litdata/chunk-0-103.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-103.bin
# upload: nsd_litdata/chunk-0-105.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-105.bin
# upload: nsd_litdata/chunk-0-107.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-107.bin
# upload: nsd_litdata/chunk-0-108.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-108.bin
# upload: nsd_litdata/chunk-0-109.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-109.bin
# upload: nsd_litdata/chunk-0-110.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-110.bin
# upload: nsd_litdata/chunk-0-111.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-111.bin
# upload: nsd_litdata/chunk-0-11.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-11.bin
# upload: nsd_litdata/chunk-0-112.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-112.bin
# upload: nsd_litdata/chunk-0-113.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-113.bin
# upload: nsd_litdata/chunk-0-114.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-114.bin
# upload: nsd_litdata/chunk-0-115.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-115.bin
# upload: nsd_litdata/chunk-0-116.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-116.bin
# upload: nsd_litdata/chunk-0-117.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-117.bin
# upload: nsd_litdata/chunk-0-118.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-118.bin
# upload: nsd_litdata/chunk-0-119.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-119.bin
# upload: nsd_litdata/chunk-0-12.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-12.bin
# upload: nsd_litdata/chunk-0-120.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-120.bin
# upload: nsd_litdata/chunk-0-121.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-121.bin
# upload: nsd_litdata/chunk-0-122.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-122.bin
# upload: nsd_litdata/chunk-0-123.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-123.bin
# upload: nsd_litdata/chunk-0-124.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-124.bin
# upload: nsd_litdata/chunk-0-125.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0-125.bin
# upload: nsd_litdata/chunk-0-126.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-0
bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-106.bin
# upload: nsd_litdata/chunk-15-107.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-107.bin
# upload: nsd_litdata/chunk-15-108.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-108.bin
# upload: nsd_litdata/chunk-15-109.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-109.bin
# upload: nsd_litdata/chunk-15-11.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-11.bin
# upload: nsd_litdata/chunk-15-110.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-110.bin
# upload: nsd_litdata/chunk-15-111.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-111.bin
# upload: nsd_litdata/chunk-15-112.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-112.bin
# upload: nsd_litdata/chunk-15-113.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-113.bin
# upload: nsd_litdata/chunk-15-114.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-114.bin
# upload: nsd_litdata/chunk-15-115.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-115.bin
# upload: nsd_litdata/chunk-15-116.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-116.bin
# upload: nsd_litdata/chunk-15-117.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-117.bin
# upload: nsd_litdata/chunk-15-118.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-118.bin
# upload: nsd_litdata/chunk-15-119.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-119.bin
# upload: nsd_litdata/chunk-15-12.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-12.bin
# upload: nsd_litdata/chunk-15-120.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-120.bin
# upload: nsd_litdata/chunk-15-121.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-121.bin
# upload: nsd_litdata/chunk-15-122.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-122.bin
# upload: nsd_litdata/chunk-15-123.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-123.bin
# upload: nsd_litdata/chunk-15-124.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-124.bin
# upload: nsd_litdata/chunk-15-125.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-125.bin
# upload: nsd_litdata/chunk-15-126.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-126.bin
# upload: nsd_litdata/chunk-15-127.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-127.bin
# upload: nsd_litdata/chunk-15-128.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-128.bin
# upload: nsd_litdata/chunk-15-129.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-129.bin
# upload: nsd_litdata/chunk-15-13.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-13.bin
# upload: nsd_litdata/chunk-15-130.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-130.bin
# upload: nsd_litdata/chunk-15-131.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-131.bin
# upload: nsd_litdata/chunk-15-132.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-132.bin
# upload: nsd_litdata/chunk-15-133.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-133.bin
# upload: nsd_litdata/chunk-15-134.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-134.bin
# upload: nsd_litdata/chunk-15-135.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-135.bin
# upload: nsd_litdata/chunk-15-136.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-136.bin
# upload: nsd_litdata/chunk-15-137.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-137.bin
# upload: nsd_litdata/chunk-15-139.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-139.bin
# upload: nsd_litdata/chunk-15-138.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-138.bin
# upload: nsd_litdata/chunk-15-14.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-14.bin
# upload: nsd_litdata/chunk-15-140.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-140.bin
# upload: nsd_litdata/chunk-15-141.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-141.bin
# upload: nsd_litdata/chunk-15-143.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-143.bin
# upload: nsd_litdata/chunk-15-142.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-142.bin
# upload: nsd_litdata/chunk-15-144.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-144.bin
# upload: nsd_litdata/chunk-15-145.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-145.bin
# upload: nsd_litdata/chunk-15-146.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-146.bin
# upload: nsd_litdata/chunk-15-147.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-147.bin
# upload: nsd_litdata/chunk-15-148.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-148.bin
# upload: nsd_litdata/chunk-15-149.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-149.bin
# upload: nsd_litdata/chunk-15-150.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-150.bin
# upload: nsd_litdata/chunk-15-15.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-15.bin
# upload: nsd_litdata/chunk-15-151.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-151.bin
# upload: nsd_litdata/chunk-15-152.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-152.bin
# upload: nsd_litdata/chunk-15-153.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-153.bin
# upload: nsd_litdata/chunk-15-154.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-154.bin
# upload: nsd_litdata/chunk-15-155.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-155.bin
# upload: nsd_litdata/chunk-15-156.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-156.bin
# upload: nsd_litdata/chunk-15-157.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-157.bin
# upload: nsd_litdata/chunk-15-158.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-158.bin
# upload: nsd_litdata/chunk-15-159.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-159.bin
# upload: nsd_litdata/chunk-15-16.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-16.bin
# upload: nsd_litdata/chunk-15-161.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-161.bin
# upload: nsd_litdata/chunk-15-160.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-160.bin
# upload: nsd_litdata/chunk-15-162.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-162.bin
# upload: nsd_litdata/chunk-15-163.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-163.bin
# upload: nsd_litdata/chunk-15-166.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-166.bin
# upload: nsd_litdata/chunk-15-165.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-165.bin
# upload: nsd_litdata/chunk-15-164.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-164.bin
# upload: nsd_litdata/chunk-15-167.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-167.bin
# upload: nsd_litdata/chunk-15-168.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-168.bin
# upload: nsd_litdata/chunk-15-17.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-17.bin
# upload: nsd_litdata/chunk-15-169.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-169.bin
# upload: nsd_litdata/chunk-15-170.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-170.bin
# upload: nsd_litdata/chunk-15-171.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-171.bin
# upload: nsd_litdata/chunk-15-172.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-172.bin
# upload: nsd_litdata/chunk-15-173.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-173.bin
# upload: nsd_litdata/chunk-15-174.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-174.bin
# upload: nsd_litdata/chunk-15-175.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-175.bin
# upload: nsd_litdata/chunk-15-176.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-176.bin
# upload: nsd_litdata/chunk-15-177.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-177.bin
# upload: nsd_litdata/chunk-15-178.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-178.bin
# upload: nsd_litdata/chunk-15-179.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-179.bin
# upload: nsd_litdata/chunk-15-18.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-18.bin
# upload: nsd_litdata/chunk-15-19.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-19.bin
# upload: nsd_litdata/chunk-15-2.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-2.bin
# upload: nsd_litdata/chunk-15-20.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-20.bin
# upload: nsd_litdata/chunk-15-21.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-21.bin
# upload: nsd_litdata/chunk-15-22.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-22.bin
# upload: nsd_litdata/chunk-15-23.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-23.bin
# upload: nsd_litdata/chunk-15-24.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-24.bin
# upload: nsd_litdata/chunk-15-25.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-25.bin
# upload: nsd_litdata/chunk-15-26.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-26.bin
# upload: nsd_litdata/chunk-15-27.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-27.bin
# upload: nsd_litdata/chunk-15-28.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-28.bin
# upload: nsd_litdata/chunk-15-29.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-29.bin
# upload: nsd_litdata/chunk-15-3.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-3.bin
# upload: nsd_litdata/chunk-15-30.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-30.bin
# upload: nsd_litdata/chunk-15-32.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-32.bin
# upload: nsd_litdata/chunk-15-31.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-31.bin
# upload: nsd_litdata/chunk-15-33.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-33.bin
# upload: nsd_litdata/chunk-15-34.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-34.bin
# upload: nsd_litdata/chunk-15-36.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-36.bin
# upload: nsd_litdata/chunk-15-35.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-35.bin
# upload: nsd_litdata/chunk-15-37.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-37.bin
# upload: nsd_litdata/chunk-15-38.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-38.bin
# upload: nsd_litdata/chunk-15-4.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-4.bin
# upload: nsd_litdata/chunk-15-40.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-40.bin
# upload: nsd_litdata/chunk-15-39.bin to s3://proj-fmri/fmri_foundation_datasets/NSD_MNI_litdata/chunk-15-39.bin
# Completed 318.3 GiB/~326.0 GiB (221.1 MiB/s) with ~37 file(s) remaining (calculating...)
